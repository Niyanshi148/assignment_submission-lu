# %% [markdown]
# # strings

# %%
name = "Niyanshi"

# %%
name.count('s')  #There is one s in the given string
# Out:
# 1

# %%
name.center(27)
# Out:
# '          Niyanshi         '

# %%
name.endswith('i')
# Out:
# True

# %%
name.encode()
# Out:
# b'Niyanshi'

# %%
name.casefold()
# Out:
# 'niyanshi'

# %%
name.endswith('k')
# Out:
# False

# %% [markdown]
# # lists

# %%
lst ={'Karan','sakshi',24,56.7,'nehal'}

# %%
print (lst)
# Out:
# {'sakshi', 'Karan', 'nehal', 24, 56.7}

# %%
lst.clear()

# %%
print(lst)
# Out:
# set()

# %%
lst ={'Karan','sakshi',24,56.7,'nehal'}

# %%
lst.pop()
# Out:
# 'sakshi'

# %%
lst
# Out:
# {24, 56.7, 'Karan', 'nehal'}

# %%
lst.add('sakshi')

# %%
lst
# Out:
# {24, 56.7, 'Karan', 'nehal', 'sakshi'}

# %%
lst.isdisjoint('karan')
# Out:
# True

# %%
lst.intersection()
# Out:
# {24, 56.7, 'Karan', 'nehal', 'sakshi'}

# %% [markdown]
# # dictionaries

# %%
students = {"student1":{"Name":'Niyanshi',"Age":20,"Branch":'Cs'},"student2":{"Name":'Nidhi',"Age":19,"Branch":'Cs'}}

# %%
students
# Out:
# {'student1': {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'},
#  'student2': {'Name': 'Nidhi', 'Age': 19, 'Branch': 'Cs'}}

# %%
students['student1']
# Out:
# {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'}

# %%
students.pop("student1")
# Out:
# {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'}

# %%
students
# Out:
# {'student2': {'Name': 'Nidhi', 'Age': 19, 'Branch': 'Cs'}}

# %%
students.update({"student1":{"Name":'Niyanshi',"Age":20,"Branch":'Cs'}})

# %%
students
# Out:
# {'student2': {'Name': 'Nidhi', 'Age': 19, 'Branch': 'Cs'},
#  'student1': {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'}}

# %%
students.items()
# Out:
# dict_items([('student2', {'Name': 'Nidhi', 'Age': 19, 'Branch': 'Cs'}), ('student1', {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'})])

# %%
students.keys()
# Out:
# dict_keys(['student2', 'student1'])

# %%
students.values()
# Out:
# dict_values([{'Name': 'Nidhi', 'Age': 19, 'Branch': 'Cs'}, {'Name': 'Niyanshi', 'Age': 20, 'Branch': 'Cs'}])
