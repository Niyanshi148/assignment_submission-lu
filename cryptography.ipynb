# %%
# !pip install cryptography

# %%
from cryptography.fernet import Fernet
def generatePasskey():
    key=Fernet.generate_key()
    print(key)
    print(type(key))
    abc=open("Password.key",'wb')
    abc.write(key)
    abc.close()

# %%
generatePasskey()
# Out:
# b'rhwx3FVr05vtgIqTsxCGyc7MZZL9U6PP3CXg1dehTG4='
# <class 'bytes'>

# %%
def getMyKey():
    abc=open("Password.key",'rb')
    return abc.read()

# %%
getMyKey()
# Out:
# b'rhwx3FVr05vtgIqTsxCGyc7MZZL9U6PP3CXg1dehTG4='

# %%
def getContentFromUser():
    return input("Enter the content you want to encrypt in your pyhton script")

# %%
getContentFromUser()
# Out:
# Enter the content you want to encrypt in your pyhton script hey, it's Niyanshi Agrawal. My First project of python.
# " hey, it's Niyanshi Agrawal. My First project of python."

# %%
def encryptMessage(message_normal):
    key = getMyKey()
    k= Fernet(key)
    encrypted_Message=k.encrypt(message_normal)
    return  encrypted_Message

# %%
 encryptMessage(b"Hey")
# Out:
# b'gAAAAABf243hZfZY9hC0GQmQv4BE8eSMtZNigzRY3p6vDxTOOShTy1j44hl4ZHoIoMEBQVEloEorLG7h-rrK5WVcEohtE1YuaQ=='

# %%
def decryptMessage(message_secret):
    key = getMyKey()
    k= Fernet(key)
    decrypted_Message=k.decrypt(message_secret)
    return  decrypted_Message

# %%
decryptMessage(b'gAAAAABf243hZfZY9hC0GQmQv4BE8eSMtZNigzRY3p6vDxTOOShTy1j44hl4ZHoIoMEBQVEloEorLG7h-rrK5WVcEohtE1YuaQ==')
# Out:
# b'Hey'
